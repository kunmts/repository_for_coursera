# %% [markdown]
# # My Jupyter Notebook in OBM Watson Studio

# %% [markdown]
# **Kun Mátyás** <br>
# Data Scientist

# %% [markdown]
# *I would liket o become a Data Scientist, becuse I belive we can improve a lot with the help of computers, models and data. I would like to make an improvement in medical field, and neuroscientist field.*

# %% [markdown]
# ### The code below computes a simple computation using the order of operations

# %%
print("2 + 2 x (6 * 2^2) =",2+2*(6+2^2))
# Out:
# 2 + 2 x (6 * 2^2) = 22

# %% [markdown]
# <a href="https://www.piday.org/million/"> First million digits of PI </a>
#
#
# |This|is|
# |----|----|
# |a|2x2|
# |table|:)|
#
# 1. milk
# 2. egg
# 3. flour
# 4. maple syrup
